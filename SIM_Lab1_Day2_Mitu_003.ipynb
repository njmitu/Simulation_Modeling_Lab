# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Creating my Personal Matrix

# %%
d1 = 3    #last digit of my student ID = 3
d2 = 0    #second last digit of my student ID = 0

A = np.array([[d1+2, d2+1], [2*d1, d2+2]])
A = np.array([[5, 1], [6, 2]])

# %% [markdown]
# 2. Analyzing Matrix A
#
#  Using NumPy, compute:
#
# ● Shape of A
#
# ● Determinant
#
# ● Rank
#
# ● Eigenvalues
#
# ● Inverse (only if determinant ≠ 0)

# %%
A = np.array([[5, 1], [6, 2]])
size_A = A.shape
det_A = np.linalg.det(A)
rank_A = np.linalg.matrix_rank(A)
eigenvalues= np.linalg.eig(A)
if np.linalg.det(A) != 0:
    inv_A = np.linalg.inv(A)
else:
    inv_A = "Matrix is Singular, cannot compute"

print("\nsize_A:\n", size_A)
print("\ndet_A:\n", det_A)
print("\nrank_A:\n", rank_A)
print("\neigenvalues:\n", eigenvalues)
print("\ninv_A:\n", inv_A)
# Out:
# size_A:
#  (2, 2)
#
# det_A:
#  3.999999999999999
#
# rank_A:
#  2
#
# eigenvalues:
#  EigResult(eigenvalues=array([6.37228132, 0.62771868]), eigenvectors=array([[ 0.58893305, -0.22295647],
#        [ 0.80818183,  0.9748284 ]]))
#
# inv_A:
#  [[ 0.5  -0.25]
#  [-1.5   1.25]]

# %% [markdown]
# 3. Value Changing Experiment
#
# Create a new matrix B by changing exactly one value in A:
#
# ● Add +1 to one element of your choice
#
# ● You must clearly state which element you changed

# %%
B = np.array([[5, 2], [6, 2]])   # adding +1 to the 2nd value of the matrix

# %% [markdown]
# 4. Re-analyze Matrix B
#
# Compute the same properties as in Step 2
#
# Using NumPy, compute:
#
# ● Shape of B
#
# ● Determinant
#
# ● Rank
#
# ● Eigenvalues
#
# ● Inverse (only if determinant ≠ 0)

# %%
B = np.array([[5, 2], [6, 2]])
size_B = B.shape
det_B = np.linalg.det(B)
rank_B = np.linalg.matrix_rank(B)
eigenvalues = np.linalg.eig(B)
if np.linalg.det(B) != 0:
    inv_B = np.linalg.inv(B)
else:
    inv_B = "Matrix is Singular, cannot compute"

print("\nsize_B:\n", size_B)
print("\ndet_B:\n", det_B)
print("\nrank_B:\n", rank_B)
print("\neigenvalues:\n", eigenvalues)
print("\ninv_B:\n", inv_B)
# Out:
# size_B:
#  (2, 2)
#
# det_B:
#  -2.0000000000000004
#
# rank_B:
#  2
#
# eigenvalues:
#  EigResult(eigenvalues=array([ 7.27491722, -0.27491722]), eigenvectors=array([[ 0.66026926, -0.3545255 ],
#        [ 0.75102896,  0.93504634]]))
#
# inv_B:
#  [[-1.   1. ]
#  [ 3.  -2.5]]

# %% [markdown]
# 5. Comparison & Explanation
#
# Answer the following in your own words:
#
# 1. How did the determinant change and why?
#
# Answer: Changing just one number (1 to 2) in the second position of the top row made the (b*c) part of the calculation larger, which flipped the determinant from positive 4 to negative 2. It shows that even a small change can significantly alter a matrix's determinant.
#
# 2. Did the rank change? Explain.
#
# 3. How did the eigenvalues respond to the value change?
#
# 4. Is B easier or harder to invert than A? Why?
